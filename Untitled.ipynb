# %% [markdown]
# # Module 4 Time Series Project
# Student: Alice
# <br>Instructor: Eli Thomas
#
# This project is based off data from kaggle on the number of covid patients in different countries.
#
# The purpose of this project will be to practice the basics of how to approach a time series project. Therefore we won't be focusing so much on the data at hand but how to call and use arima and fbprophet.
# We mention this because we shorten our data significantly to use arima and a different example data to use fbprophet.
#
# To be continued:
# A more 'advanced' study of this data will be provided soon...

# %%
from fbprophet import Prophet
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import plotly.graph_objects as go
import datetime 

import pycountry
import plotly.express as px

# %%
data = pd.read_csv('covid_data.csv')

# %%
data
# Out:
#          province        country   latitude   longitude  confirmed_cases  \
# 0           Hubei          China  35.861660  104.195397              729
# 1       Guangdong          China  35.861660  104.195397               53
# 2        Zhejiang          China  35.861660  104.195397               43
# 3         Beijing          China  35.861660  104.195397               36
# 4       Chongqing          China  35.861660  104.195397               27
# ...           ...            ...        ...         ...              ...
# 24786    Nebraska             US  37.090240  -95.712891                5
# 24787         NaN        Reunion        NaN         NaN                1
# 24788         NaN  Cote d'Ivoire        NaN         NaN                1
# 24789         NaN         Greece  39.074208   21.824312               99
# 24790  California             US  37.090240  -95.712891              177
#
#        deaths  recovered          update_time data_source country_code  \
# 0        39.0        NaN  2020-01-24 14:55:00         bno          CHN
# 1         0.0        NaN  2020-01-24 14:55:00         bno          CHN
# 2         0.0        NaN  2020-01-24 14:55:00         bno          CHN
# 3         0.0        NaN  2020-01-24 14:55:00         bno          CHN
# 4         0.0        NaN  2020-01-24 14:55:00         bno          CHN
# ...       ...        ...                  ...         ...          ...
# 24786     0.0        0.0      3/11/2020 23:13         jhu          USA
# 24787     0.0        0.0      3/11/2020 23:13         jhu          NaN
# 24788     0.0        0.0      3/11/2020 23:33         jhu          CIV
# 24789     1.0        0.0      3/11/2020 23:53         jhu          GRC
# 24790     3.0        2.0      3/11/2020 23:53         jhu          USA
#
#          region                                country_flag
# 0          Asia  https://www.countryflags.io/cn/flat/64.png
# 1          Asia  https://www.countryflags.io/cn/flat/64.png
# 2          Asia  https://www.countryflags.io/cn/flat/64.png
# 3          Asia  https://www.countryflags.io/cn/flat/64.png
# 4          Asia  https://www.countryflags.io/cn/flat/64.png
# ...         ...                                         ...
# 24786  Americas  https://www.countryflags.io/us/flat/64.png
# 24787       NaN                                         NaN
# 24788    Africa  https://www.countryflags.io/ci/flat/64.png
# 24789    Europe  https://www.countryflags.io/gr/flat/64.png
# 24790  Americas  https://www.countryflags.io/us/flat/64.png
#
# [24791 rows x 12 columns]

# %%
data.head()
# Out:
#     province country  latitude   longitude  confirmed_cases  deaths  \
# 0      Hubei   China  35.86166  104.195397              729    39.0
# 1  Guangdong   China  35.86166  104.195397               53     0.0
# 2   Zhejiang   China  35.86166  104.195397               43     0.0
# 3    Beijing   China  35.86166  104.195397               36     0.0
# 4  Chongqing   China  35.86166  104.195397               27     0.0
#
#    recovered          update_time data_source country_code region  \
# 0        NaN  2020-01-24 14:55:00         bno          CHN   Asia
# 1        NaN  2020-01-24 14:55:00         bno          CHN   Asia
# 2        NaN  2020-01-24 14:55:00         bno          CHN   Asia
# 3        NaN  2020-01-24 14:55:00         bno          CHN   Asia
# 4        NaN  2020-01-24 14:55:00         bno          CHN   Asia
#
#                                  country_flag
# 0  https://www.countryflags.io/cn/flat/64.png
# 1  https://www.countryflags.io/cn/flat/64.png
# 2  https://www.countryflags.io/cn/flat/64.png
# 3  https://www.countryflags.io/cn/flat/64.png
# 4  https://www.countryflags.io/cn/flat/64.png

# %% [markdown]
# ## Cleaning Data

# %%
data = data.drop('country_flag', axis =1)

# %%
data['update_time'] = pd.to_datetime(data['update_time'])

# %%
data['update_date'] = data['update_time'].dt.date

# %%
df = data[data.data_source=='jhu']
df_agg = df.groupby('update_date').agg({'confirmed_cases':'sum','deaths':'sum','recovered':'sum'}).reset_index()

# %%
fig = go.Figure()
fig.add_trace(go.Bar(x=df_agg['update_date'],
                y=df_agg['confirmed_cases'],
                name='Confirmed',
                marker_color='blue'
                ))
fig.add_trace(go.Bar(x=df_agg['update_date'],
                y=df_agg['deaths'],
                name='Deaths',
                marker_color='Red'
                ))
fig.add_trace(go.Bar(x=df_agg['update_date'],
                y=df_agg['recovered'],
                name='Recovered',
                marker_color='Green'
                ))

fig.update_layout(
    title='Worldwide Corona Virus Cases - Confirmed, Deaths, Recovered',
    xaxis_tickfont_size=14,
    yaxis=dict(
        title='Number of Cases',
        titlefont_size=16,
        tickfont_size=14,
    ),
    legend=dict(
        x=0,
        y=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'
    ),
    barmode='group',
    bargap=0.15, # gap between bars of adjacent location coordinates.
    bargroupgap=0.1 # gap between bars of the same location coordinate.
)
fig.show()
# Out:
# <div>
#
#
#             <div id="390721f9-b5dc-41fa-8277-55a72bbd6747" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("390721f9-b5dc-41fa-8277-55a72bbd6747")) {
#                     Plotly.newPlot(
#                         '390721f9-b5dc-41fa-8277-55a72bbd6747',
#                         [{"marker": {"color": "blue"}, "name": "Confirmed", "type": "bar", "x": ["2020-01-22", "2020-01-23", "2020-01-24", "2020-01-25", "2020-01-26", "2020-01-27", "2020-01-28", "2020-01-29", "2020-01-30", "2020-01-31", "2020-02-01", "2020-02-02", "2020-02-03", "2020-02-04", "2020-02-05", "2020-02-06", "2020-02-07", "2020-02-08", "2020-02-09", "2020-02-10", "2020-02-11", "2020-02-12", "2020-02-13", "2020-02-14", "2020-02-15", "2020-02-16", "2020-02-17", "2020-02-18", "2020-02-19", "2020-02-20", "2020-02-21", "2020-02-22", "2020-02-23", "2020-02-24", "2020-02-25", "2020-02-26", "2020-02-27", "2020-02-28", "2020-02-29", "2020-03-01", "2020-03-02", "2020-03-03", "2020-03-04", "2020-03-05", "2020-03-06", "2020-03-07", "2020-03-08", "2020-03-09", "2020-03-10", "2020-03-11"], "y": [555, 653, 941, 1438, 2118, 2927, 5578, 6165, 8235, 10151, 12287, 16804, 19902, 24027, 27587, 30798, 34485, 37078, 40326, 42696, 44584, 45590, 60636, 66634, 69112, 71197, 73273, 75029, 75634, 77227, 76959, 77612, 80435, 78714, 79768, 82246, 82524, 83702, 86502, 87613, 91481, 94702, 93966, 97461, 106264, 105057, 113831, 108040, 114303, 125681]}, {"marker": {"color": "Red"}, "name": "Deaths", "type": "bar", "x": ["2020-01-22", "2020-01-23", "2020-01-24", "2020-01-25", "2020-01-26", "2020-01-27", "2020-01-28", "2020-01-29", "2020-01-30", "2020-01-31", "2020-02-01", "2020-02-02", "2020-02-03", "2020-02-04", "2020-02-05", "2020-02-06", "2020-02-07", "2020-02-08", "2020-02-09", "2020-02-10", "2020-02-11", "2020-02-12", "2020-02-13", "2020-02-14", "2020-02-15", "2020-02-16", "2020-02-17", "2020-02-18", "2020-02-19", "2020-02-20", "2020-02-21", "2020-02-22", "2020-02-23", "2020-02-24", "2020-02-25", "2020-02-26", "2020-02-27", "2020-02-28", "2020-02-29", "2020-03-01", "2020-03-02", "2020-03-03", "2020-03-04", "2020-03-05", "2020-03-06", "2020-03-07", "2020-03-08", "2020-03-09", "2020-03-10", "2020-03-11"], "y": [17.0, 18.0, 26.0, 42.0, 56.0, 82.0, 131.0, 133.0, 171.0, 213.0, 259.0, 366.0, 425.0, 491.0, 563.0, 633.0, 723.0, 805.0, 905.0, 1012.0, 1112.0, 1140.0, 1372.0, 1521.0, 1673.0, 1768.0, 1867.0, 2004.0, 2120.0, 2249.0, 2250.0, 2451.0, 2475.0, 2626.0, 2702.0, 2774.0, 2816.0, 2867.0, 2942.0, 2994.0, 3091.0, 3176.0, 3248.0, 3350.0, 3489.0, 3553.0, 3881.0, 3920.0, 4207.0, 4615.0]}, {"marker": {"color": "Green"}, "name": "Recovered", "type": "bar", "x": ["2020-01-22", "2020-01-23", "2020-01-24", "2020-01-25", "2020-01-26", "2020-01-27", "2020-01-28", "2020-01-29", "2020-01-30", "2020-01-31", "2020-02-01", "2020-02-02", "2020-02-03", "2020-02-04", "2020-02-05", "2020-02-06", "2020-02-07", "2020-02-08", "2020-02-09", "2020-02-10", "2020-02-11", "2020-02-12", "2020-02-13", "2020-02-14", "2020-02-15", "2020-02-16", "2020-02-17", "2020-02-18", "2020-02-19", "2020-02-20", "2020-02-21", "2020-02-22", "2020-02-23", "2020-02-24", "2020-02-25", "2020-02-26", "2020-02-27", "2020-02-28", "2020-02-29", "2020-03-01", "2020-03-02", "2020-03-03", "2020-03-04", "2020-03-05", "2020-03-06", "2020-03-07", "2020-03-08", "2020-03-09", "2020-03-10", "2020-03-11"], "y": [28.0, 30.0, 36.0, 39.0, 52.0, 61.0, 107.0, 126.0, 143.0, 239.0, 288.0, 463.0, 617.0, 866.0, 1120.0, 1507.0, 2000.0, 2660.0, 3313.0, 3905.0, 4689.0, 5320.0, 6531.0, 7952.0, 9477.0, 10911.0, 12590.0, 14315.0, 16136.0, 18060.0, 19442.0, 22613.0, 23452.0, 25128.0, 27997.0, 30422.0, 33683.0, 36268.0, 39634.0, 42695.0, 46201.0, 48707.0, 50728.0, 54137.0, 57671.0, 58197.0, 64906.0, 58658.0, 60883.0, 66989.0]}],
#                         {"bargap": 0.15, "bargroupgap": 0.1, "barmode": "group", "legend": {"bgcolor": "rgba(255, 255, 255, 0)", "bordercolor": "rgba(255, 255, 255, 0)", "x": 0, "y": 1.0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type"

# %%
data = data[(data['country'] != 'Others') & (data['country'] != 'Undisclosed')]

# %%
print("\nTotal countries affected by COVID-19: ",len(data.country.unique()))
# Out:
# Total countries affected by COVID-19:  138

# %% [markdown]
# ## Exploring Data

# %% [markdown]
# We take the latest date/ timestamp, and create a new dataframe to only include the latest day data.

# %%
from datetime import date
latest_date = data['update_time'].max()

year = latest_date.year
month = latest_date.month
# adjust for timezone
day = latest_date.day - 1


data_latest = data[data['update_time'] > pd.Timestamp(date(year,month,day))]

# %%
# Creating a dataframe with total no of confirmed cases for every country as of the latest available date
affected_country_latest = data_latest.groupby(['country','country_code','region','latitude','longitude']).agg({'update_time': np.max}).reset_index()
key = ['country','country_code','region','latitude','longitude','update_time']
global_cases = pd.merge(data_latest, affected_country_latest, how='inner', on=key).drop_duplicates().groupby(key).max().sort_values(by=['confirmed_cases'],ascending=False).reset_index()
global_cases.index+=1
global_cases_columns = global_cases.columns.tolist()
global_cases_columns.remove('update_time')
global_cases = global_cases[global_cases_columns]

# %%
global_cases.head()
# Out:
#    country country_code  region   latitude  longitude province  \
# 1    Italy          ITA  Europe  41.871940  12.567380      NaN
# 2     Iran          IRN    Asia  32.427908  53.688046      NaN
# 3   France          FRA  Europe  46.227638   2.213749   France
# 4    Spain          ESP  Europe  40.463667  -3.749220      NaN
# 5  Germany          DEU  Europe  51.165691  10.451526      NaN
#
#    confirmed_cases  deaths  recovered data_source update_date
# 1            12462   827.0     1045.0         jhu  2020-03-11
# 2             9000   354.0     2959.0         jhu  2020-03-11
# 3             2281    48.0       12.0         jhu  2020-03-11
# 4             2277    54.0      183.0         jhu  2020-03-11
# 5             1908     3.0       25.0         jhu  2020-03-11

# %%
import folium

# %%
url = 'https://raw.githubusercontent.com/python-visualization/folium/master/examples/data'
world_geo = f'{url}/world-countries.json'

m = folium.Map(location=[35.86166,104.195397], zoom_start=3,tiles='Stamen Toner')

folium.Choropleth(
    geo_data=world_geo,
    name='choropleth',
    data=global_cases,
    columns=['country', 'confirmed_cases'],
    key_on='feature.properties.name',
    fill_color='OrRd',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Number of Confirmed Cases'
).add_to(m)

for lat, lon, value, name in zip(global_cases['latitude'], global_cases['longitude'], global_cases['confirmed_cases'], global_cases['country']):
    folium.CircleMarker(
        [lat, lon],
        radius=10,
        popup = ('<strong>Country</strong>: ' + str(name).capitalize() + '<br>'
                 '<strong>Confirmed Cases</strong>: ' + str(value) + '<br>'),        
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7
    ).add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
#Mainland China
key = ['province','country']
China = data_latest[data_latest['country']=='China'].groupby(key).agg({'confirmed_cases':np.max,'deaths':np.max,'recovered':np.max,'update_date':np.max}).fillna(0).reset_index()
China['log_confirmed_cases'] = np.log(China['confirmed_cases'])
China['log_recovered'] = np.log(China['recovered'])
China['log_deaths'] = np.log(China['deaths'])
China['norm_confirmed_cases'] = scaler.fit_transform(China[['confirmed_cases']])
China['norm_recovered'] = scaler.fit_transform(China[['recovered']])
China['norm_deaths'] = scaler.fit_transform(China[['deaths']])
China = China.sort_values(by='confirmed_cases',ascending=False)

# %%
f, ax = plt.subplots(figsize=(12, 8))

sns.set_color_codes("pastel")

sns.barplot(x="confirmed_cases", y="province", data=China[1:],
            label="confirmed_cases", color="salmon")

sns.set_color_codes("muted")
sns.barplot(x="recovered", y="province", data=China[1:],
            label="recovered", color ='skyblue')

# Add a legend and informative axis label
ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(xlim=(0, 1500), ylabel="",xlabel="# cases",title="Confirmed vs Recovered")
sns.despine(left=True, bottom=True)

# %% [markdown]
# ## Time Series on Provinces of China

# %%
China_df = data[data['country']=='China']

# %% [markdown]
# ### Data Cleaning

# %%
China_df = China_df.drop('recovered', axis = 1)
China_df = China_df.drop_duplicates()

# %% [markdown]
# We are interested in the number of cases, we will drop recovery as significant portion of our data is missing. We will also fill missing values (2 missing: latitude and longitude for Hong Kong and Taiwan).

# %%
China_df.fillna(0, inplace = True)

# %%
missing = China_df[(China_df['latitude'] == 0) & (China_df['longitude'] == 0)]

# %%
missing
# Out:
#         province country  latitude  longitude  confirmed_cases  deaths  \
# 24589     Taiwan   China       0.0        0.0               47     1.0
# 24614  Hong Kong   China       0.0        0.0              120     3.0
#
#               update_time data_source country_code region update_date
# 24589 2020-03-10 19:13:00         jhu          CHN   Asia  2020-03-10
# 24614 2020-03-10 23:53:00         jhu          CHN   Asia  2020-03-10

# %% [markdown]
# Missing latitude and Longitude
# <br>Taiwan: 23.6978 latitude, 120.9605 longitude
# <br>Hong Kong: 22.3193 latitude, 114.1694 longitude

# %%
#changing to list of lists 
df_to_list = China_df.to_numpy().tolist()

# %%
for x in df_to_list:
    if x[0] == 'Taiwan':
        x[2] = 23.6978
        x[3] = 120.9605
    elif x[0] == 'Hong Kong':
        x[2]= 22.3193
        x[3] = 114.1694

# %%
#change back to df
China_df = pd.DataFrame(df_to_list, columns=China_df.columns)

# %%
China_df['update_day'] = China_df['update_time'].dt.day

# %% [markdown]
# From China we look at the top 5 provinces which has the fastest growing confirmed cases. We will do this be first selecting ten provinces with the most cases over time. Then seeing growth speed by plotting.

# %%
China_province_df = China_df.groupby('province', as_index=False)['confirmed_cases'].mean().sort_values(by = 'confirmed_cases', ascending = True)
China_province_df = China_province_df.tail(10)
China_province_df
# Out:
#      province  confirmed_cases
# 24   Shandong       240.220820
# 16    Jiangsu       254.849835
# 2   Chongqing       265.279180
# 17    Jiangxi       367.561514
# 0       Anhui       383.378764
# 14      Hunan       452.580442
# 11      Henan       525.882911
# 5   Guangdong       605.359621
# 33   Zhejiang       609.678233
# 13      Hubei     13865.134069

# %%
column = ['latitude', 'longitude', 'deaths', 'update_day']

# %%
Shandong_df = China_df[China_df['province']== 'Shandong'].groupby('update_date').sum().drop(column, axis =1)
Jiangsu_df = China_df[China_df['province']== 'Jiangsu'].groupby('update_date').sum().drop(column, axis =1)
Chonqing_df = China_df[China_df['province']== 'Chongqing'].groupby('update_date').sum().drop(column, axis =1)
Jiangxi_df = China_df[China_df['province']== 'Jiangxi'].groupby('update_date').sum().drop(column, axis =1)
Anhui_df = China_df[China_df['province']== 'Anhui'].groupby('update_date').sum().drop(column, axis =1)
Hunan_df = China_df[China_df['province']== 'Hunan'].groupby('update_date').sum().drop(column, axis =1)
Henan_df = China_df[China_df['province']== 'Henan'].groupby('update_date').sum().drop(column, axis =1)
Zhejiang_df = China_df[China_df['province']== 'Zhejiang'].groupby('update_date').sum().drop(column, axis =1)
Jilin_df = China_df[China_df['province']== 'Jilin'].groupby('update_date').sum().drop(column, axis =1)
Hubei_df = China_df[China_df['province']== 'Hubei'].groupby('update_date').sum().drop(column, axis =1)

# %%
List = [Shandong_df,Jiangsu_df,Chonqing_df,Jiangxi_df,Anhui_df,Hunan_df,Henan_df,Zhejiang_df,Jilin_df,Hubei_df]

# %%
plt.figure(figsize=(15,10))
plt.grid(True)
for i,x in enumerate(List):
    plt.plot(x, label = i)
plt.legend()

# %% [markdown]
# Since Hubei has a large number of cases we exclude Hubei.

# %%
plt.figure(figsize=(15,10))
plt.grid(True)
for i,x in enumerate(List[:9]):
    plt.plot(x, label = i)
plt.legend()

# %% [markdown]
# All provinces seem to grow at the same rate, so we will just choose the top five with the most cases: Hunan, Henan, Zhejiang, Jilin, Hubei.

# %% [markdown]
# ## Trend and Seasonality

# %%
list_provinces = [Hunan_df,Henan_df,Zhejiang_df,Jilin_df,Hubei_df]
provinces_dict = {'Hunan': Hunan_df,
                 'Henan': Henan_df,
                 'Guangdong': Zhejiang_df,
                 'Zhejiang': Jilin_df,
                 'Hubei': Hubei_df}

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

def seasonality(df, column_of_graph, frequency):
    '''
    parameters: df <dataframe>, column_of_graph <int> which column your graphs should take,
                frequency <int> 
    returns: trend, seasonality and noise of decomposed object on three consecutive axes.
    '''
    decomposition = seasonal_decompose(df, freq = frequency)
    
    decomposition.trend.plot(ax=axes[0][column_of_graph])
    axes[0][column_of_graph].set_ylabel('Trend')
    decomposition.seasonal.plot(ax=axes[1][column_of_graph])
    axes[1][column_of_graph].set_ylabel('Seasonal')
    decomposition.resid.plot(ax=axes[2][column_of_graph])
    axes[2][column_of_graph].set_ylabel('Residual')

# %%
import warnings
warnings.filterwarnings('ignore')
fig, axes = plt.subplots(3,5, figsize=(20,12))
for i, df in enumerate(list_provinces): 
    seasonality(df, i, 5)
fig.tight_layout()
plt.show()

# %% [markdown]
# ## Stationary Test

# %%
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller

# %%
#ADF test
def ADF_test(df):
    '''
    parameters: df <dataframe>
    returns: stationary or non stationary using ADF test
    '''
    X = df['confirmed_cases'].values
    result = adfuller(X)

    print('ADF statistic:', result[0])
    print('p-value:',  result[1])
    print('critical values:')
    for key, value in result[4].items():
        print('\t%s: %.3f' % (key,value))

    #reject null-hypothesis for critical value .05
    if result[0]< result[4]['5%']:
        print('stationary')
    else:
        print('non-stationary')

# %%
for key, value in provinces_dict.items():
    print(key)
    ADF_test(value)
    print('---------------------------')
# Out:
# Hunan
# ADF statistic: -1.5856822880503298
# p-value: 0.49078167793404887
# critical values:
# 	1%: -3.593
# 	5%: -2.932
# 	10%: -2.604
# non-stationary
# ---------------------------
# Henan
# ADF statistic: -1.639919939899415
# p-value: 0.4623026268675926
# critical values:
# 	1%: -3.581
# 	5%: -2.927
# 	10%: -2.602
# non-stationary
# ---------------------------
# Guangdong
# ADF statistic: -1.5968811728408636
# p-value: 0.4851599879430026
# critical values:
# 	1%: -3.593
# 	5%: -2.932
# 	10%: -2.604
# non-stationary
# ---------------------------
# Zhejiang
# ADF statistic: -1.8493562556312442
# p-value: 0.3562473454921965
# critical values:
# 	1%: -3.589
# 	5%: -2.930
# 	10%: -2.603
# non-stationary
# ---------------------------
# Hubei
# ADF statistic: -1.8891672666213384
# p-value: 0.3371742048902666
# critical values:
# 	1%: -3.575
# 	5%: -2.924
# 	10%: -2.600
# non-stationary
# ---------------------------

# %%
indexed_data = China_df.set_index(['update_time'])

# %%
China_df['hour'] = China_df['update_time'].dt.hour

# %%
def rolling(df, x, n):
    df[x] = df['confirmed_cases'].rolling(n, center = True).mean()

for df in list_provinces:
    rolling(df, 'MA_7', 7)
    rolling(df, 'MA_10', 10)

# %%
for key, df in provinces_dict.items():
    plt.figure(figsize=(15,10))
    plt.grid(True)
    plt.title(key)
    plt.plot(df['confirmed_cases'], label = 'confirmed cases')
    plt.plot(df['MA_7'], label = 'MA 7 day')
    plt.plot(df['MA_10'], label = 'MA 10 day')
    plt.legend(loc=2)

# %% [markdown]
# ## Autocorrelation

# %%
from statsmodels.graphics.tsaplots import plot_pacf,plot_acf
from matplotlib.pylab import rcParams

def autocorrelation(df, lags, col):
    plot_acf(df, lags=lags, ax=ax[0][col])
    plot_pacf(df, lags=lags, ax=ax[1][col])

# %%
for df in list_provinces:
    df.drop(['MA_7', 'MA_10'], axis =1, inplace =True)

# %%
fig,ax = plt.subplots(2,5,figsize=(20,12))

for i, df in enumerate(list_provinces): 
    autocorrelation(df, 7 , i)
fig.tight_layout()
plt.show()

# %%
pd.plotting.autocorrelation_plot(Hunan_df)

# %%
pd.plotting.autocorrelation_plot(Henan_df)

# %%
pd.plotting.autocorrelation_plot(Zhejiang_df)

# %%
pd.plotting.autocorrelation_plot(Jilin_df)

# %%
pd.plotting.autocorrelation_plot(Hubei_df)

# %%
from sklearn.metrics import mean_squared_error
import pmdarima as pm

def arima_model(train, test):
    model = pm.auto_arima(train, trace=True,error_action='ignore', suppress_warnings=True)
    model.fit(train)

    print(model.summary())
    model.plot_diagnostics(figsize=(8, 8))
    plt.show()
    forecast1 = model.predict(n_periods=len(test))
    forecast1 = pd.DataFrame(forecast1,index = test.index,columns=['Prediction'])

    #plot the predictions for test set
    plt.plot(train, label='Train')
    plt.plot(test, label='Test')
    plt.plot(forecast1, label='Prediction')
    plt.show();

    test['predicted_value']=forecast1
    test.head()


    MSE = mean_squared_error(test.confirmed_cases, test.predicted_value)
    print ('MSE: {}'.format(MSE))

# %%
#Hunan_df,Henan_df,Zhejiang_df,Jilin_df,Hubei_df

# %%
def train_test(df):
    train = df.head(int(len(df)*(70/100)))
    test = df.tail(int(len(df)*(30/100)))
    return (train,test)

# %%
Hunan_train, Hunan_test = train_test(Hunan_df)
Henan_train, Henan_test = train_test(Henan_df)
Zhejiang_train, Zhejiang_test = train_test(Zhejiang_df)
Jilin_train, Jilin_test = train_test(Jilin_df)
Hubei_train, Hubei_test = train_test(Hubei_df)

# %%
train_list = []
test_list = []

for df in list_provinces:
    train_list.append(train_test(df)[0])
    test_list.append(train_test(df)[1])

# %%
for train, test in zip(train_list, test_list):
    arima_model(train, test)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.13 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=739.483, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=670.358, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.07 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=757.459, Time=0.01 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=668.300, Time=0.03 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=669.888, Time=0.03 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.16 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=668.997, Time=0.03 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.18 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=667.136, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=668.699, Time=0.02 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=668.953, Time=0.03 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=668.347, Time=0.03 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=667.799, Time=0.02 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=670.290, Time=0.06 sec
#
# Best model:  ARIMA(2,0,0)(0,0,0)[0]
# Total fit time: 0.855 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   35
# Model:               SARIMAX(2, 0, 0)   Log Likelihood                -330.568
# Date:                Mon, 05 Oct 2020   AIC                            667.136
# Time:                        12:36:19   BIC                            671.802
# Sample:                             0   HQIC                           668.747
#                                  - 35
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.2430      0.198      6.290      0.000       0.856       1.630
# ar.L2         -0.3043      0.183     -1.666      0.096      -0.662       0.054
# sigma2      9.167e+06   2.82e-08   3.25e+14      0.000    9.17e+06    9.17e+06
# ===================================================================================
# Ljung-Box (Q):                       14.40   Jarque-Bera (JB):               101.75
# Prob(Q):                              1.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.01   Skew:                            -1.93
# Prob(H) (two-sided):                  0.00   Kurtosis:                        10.41
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 7.86e+29. Standard errors may be unstable.
# MSE: 279395.71718984906
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.34 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=709.459, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=646.936, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.08 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=726.858, Time=0.01 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=644.742, Time=0.02 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=646.399, Time=0.04 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=646.539, Time=0.09 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=645.517, Time=0.04 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=648.178, Time=0.15 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=643.644, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=645.286, Time=0.01 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=645.525, Time=0.02 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=645.182, Time=1.10 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=644.358, Time=0.03 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=647.090, Time=0.11 sec
#
# Best model:  ARIMA(2,0,0)(0,0,0)[0]
# Total fit time: 2.129 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   33
# Model:               SARIMAX(2, 0, 0)   Log Likelihood                -318.822
# Date:                Mon, 05 Oct 2020   AIC                            643.644
# Time:                        12:36:22   BIC                            648.134
# Sample:                             0   HQIC                           645.155
#                                  - 33
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.2504      0.205      6.105      0.000       0.849       1.652
# ar.L2         -0.3156      0.188     -1.680      0.093      -0.684       0.053
# sigma2      1.413e+07   2.01e-08   7.04e+14      0.000    1.41e+07    1.41e+07
# ===================================================================================
# Ljung-Box (Q):                       11.64   Jarque-Bera (JB):                92.02
# Prob(Q):                              1.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.06   Skew:                            -1.91
# Prob(H) (two-sided):                  0.00   Kurtosis:                        10.24
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number  8e+29. Standard errors may be unstable.
# MSE: 443666.9187283778
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.13 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=760.361, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=688.843, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.05 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=778.528, Time=0.00 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=686.328, Time=0.03 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=687.533, Time=0.03 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=682.154, Time=0.14 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=687.128, Time=0.06 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=688.888, Time=0.07 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=688.718, Time=0.08 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : AIC=693.539, Time=0.14 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=686.067, Time=0.03 sec
#
# Best model:  ARIMA(2,0,1)(0,0,0)[0] intercept
# Total fit time: 0.790 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   35
# Model:               SARIMAX(2, 0, 1)   Log Likelihood                -336.077
# Date:                Mon, 05 Oct 2020   AIC                            682.154
# Time:                        12:36:24   BIC                            689.931
# Sample:                             0   HQIC                           684.839
#                                  - 35
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept    544.0464    380.606      1.429      0.153    -201.928    1290.021
# ar.L1          1.8967      0.076     24.962      0.000       1.748       2.046
# ar.L2         -0.9421      0.081    -11.634      0.000      -1.101      -0.783
# ma.L1         -0.9732      0.307     -3.173      0.002      -1.574      -0.372
# sigma2      1.351e+07      0.003   4.08e+09      0.000    1.35e+07    1.35e+07
# ===================================================================================
# Ljung-Box (Q):                       18.74   Jarque-Bera (JB):                36.94
# Prob(Q):                              0.98   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.64   Skew:                            -1.18
# Prob(H) (two-sided):                  0.45   Kurtosis:                         7.44
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 9.88e+25. Standard errors may be unstable.
# MSE: 294227455.8031661
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.15 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=517.994, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=459.759, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.05 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=533.197, Time=0.02 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=455.448, Time=0.12 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=457.238, Time=0.17 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.15 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=456.077, Time=0.06 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.22 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=454.670, Time=0.06 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=458.278, Time=0.04 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=456.619, Time=0.09 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=456.470, Time=0.13 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=454.963, Time=0.05 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=inf, Time=0.08 sec
#
# Best model:  ARIMA(2,0,0)(0,0,0)[0]
# Total fit time: 1.449 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   32
# Model:               SARIMAX(2, 0, 0)   Log Likelihood                -224.335
# Date:                Mon, 05 Oct 2020   AIC                            454.670
# Time:                        12:36:26   BIC                            459.068
# Sample:                             0   HQIC                           456.128
#                                  - 32
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.3159      0.190      6.916      0.000       0.943       1.689
# ar.L2         -0.3900      0.182     -2.145      0.032      -0.746      -0.034
# sigma2       6.63e+04   1.24e+04      5.366      0.000    4.21e+04    9.05e+04
# ===================================================================================
# Ljung-Box (Q):                        9.02   Jarque-Bera (JB):                94.71
# Prob(Q):                              1.00   Prob(JB):                         0.00
# Heteroskedasticity (H):              16.57   Skew:                            -1.91
# Prob(H) (two-sided):                  0.00   Kurtosis:                        10.51
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# MSE: 2987.5916197416914
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=913.849, Time=0.09 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=974.525, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=914.315, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=952.168, Time=0.01 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=992.429, Time=0.01 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=915.480, Time=0.03 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=914.401, Time=0.03 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : AIC=914.893, Time=0.11 sec
#  ARIMA(2,0,3)(0,0,0)[0] intercept   : AIC=916.658, Time=0.08 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=912.659, Time=0.04 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=950.147, Time=0.04 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=912.260, Time=0.03 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=914.196, Time=0.05 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=912.878, Time=0.12 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=911.512, Time=0.03 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=912.913, Time=0.02 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=913.563, Time=0.05 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=913.553, Time=0.09 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=911.834, Time=0.03 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=912.298, Time=0.10 sec
#
# Best model:  ARIMA(2,0,0)(0,0,0)[0]
# Total fit time: 0.995 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   35
# Model:               SARIMAX(2, 0, 0)   Log Likelihood                -452.756
# Date:                Mon, 05 Oct 2020   AIC                            911.512
# Time:                        12:36:28   BIC                            916.178
# Sample:                             0   HQIC                           913.123
#                                  - 35
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.2215      0.228      5.357      0.000       0.775       1.668
# ar.L2         -0.2977      0.209     -1.424      0.155      -0.708       0.112
# sigma2      9.944e+09   3.48e-11   2.86e+20      0.000    9.94e+09    9.94e+09
# ===================================================================================
# Ljung-Box (Q):                        8.78   Jarque-Bera (JB):               188.35
# Prob(Q):                              1.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.04   Skew:                            -2.27
# Prob(H) (two-sided):                  0.00   Kurtosis:                        13.41
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 2.65e+36. Standard errors may be unstable.
# MSE: 1634289248.5053706

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
def forecast_graph(train,test,n):
    model = ARIMA(train, order=(1, 1, 1))  
    fitted = model.fit(disp=-1)  

    # Forecast
    fc, se, conf = fitted.forecast(n, alpha=0.05)  # 95% conf

    # Make as pandas series
    fc_series = pd.Series(fc, index=test.index)
    lower_series = pd.Series(conf[:, 0], index=test.index)
    upper_series = pd.Series(conf[:, 1], index=test.index)

    # Plot
    plt.figure(figsize=(12,5), dpi=100)
    plt.plot(train, label='training')
    plt.plot(test, label='actual')
    plt.plot(fc_series, label='forecast')
    plt.fill_between(lower_series.index, lower_series, upper_series, 
                 color='k', alpha=.15)
    plt.title('Forecast vs Actuals')
    plt.legend(loc='upper left', fontsize=8)
    plt.show()

# %%
for train,test in zip(train_list[:4], test_list[:4]):
    forecast_graph(train,test,len(test.index))

# %%
for train,test in zip(train_list, test_list):
    model = pm.auto_arima(train, trace=True,error_action='ignore', suppress_warnings=True)
    #model.fit(train)
    # Forecast
    n_periods = 24
    fc, confint = model.predict(n_periods=n_periods, return_conf_int=True)
    index_of_fc = np.arange(len(df.values), len(df.values)+n_periods)

    # make series for plotting purpose
    fc_series = pd.Series(fc, index=index_of_fc)
    lower_series = pd.Series(confint[:, 0], index=index_of_fc)
    upper_series = pd.Series(confint[:, 1], index=index_of_fc)

    # Plot
    plt.plot(df.values)
    plt.plot(fc_series, color='darkgreen')
    plt.fill_between(lower_series.index, 
                 lower_series, 
                 upper_series, 
                 color='k', alpha=.15)

    plt.title("Final Forecast")
    plt.show()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.21 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=739.483, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=670.358, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.08 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=757.459, Time=0.01 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=668.300, Time=0.02 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=669.888, Time=0.03 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.18 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=668.997, Time=0.03 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.22 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=667.136, Time=0.03 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=668.699, Time=0.02 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=668.953, Time=0.02 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=668.347, Time=0.03 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=667.799, Time=0.02 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=670.290, Time=0.06 sec
#
# Best model:  ARIMA(2,0,0)(0,0,0)[0]
# Total fit time: 0.984 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.41 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=709.459, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=646.936, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.08 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=726.858, Time=0.01 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=644.742, Time=0.05 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=646.399, Time=0.10 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=646.539, Time=0.10 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=645.517, Time=0.05 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=648.178, Time=0.23 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=643.644, Time=0.04 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=645.286, Time=0.02 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=645.525, Time=0.03 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=645.182, Time=0.04 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=644.358, Time=0.03 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=647.090, Time=0.30 sec
#
# Best model:  ARIMA(2,0,0)(0,0,0)[0]
# Total fit time: 1.531 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.21 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=760.361, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=688.843, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.06 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=778.528, Time=0.00 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=686.328, Time=0.02 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=687.533, Time=0.03 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=682.154, Time=0.20 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=687.128, Time=0.07 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=688.888, Time=0.06 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=688.718, Time=0.09 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : AIC=693.539, Time=0.10 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=686.067, Time=0.03 sec
#
# Best model:  ARIMA(2,0,1)(0,0,0)[0] intercept
# Total fit time: 0.917 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.24 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=517.994, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=459.759, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.02 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=533.197, Time=0.01 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=455.448, Time=0.05 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=457.238, Time=0.08 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.12 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=456.077, Time=0.04 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.09 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=454.670, Time=0.03 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=458.278, Time=0.02 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=456.619, Time=0.05 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=456.470, Time=0.08 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=454.963, Time=0.07 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=inf, Time=0.11 sec
#
# Best model:  ARIMA(2,0,0)(0,0,0)[0]
# Total fit time: 1.060 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=913.849, Time=0.15 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=974.525, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=914.315, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=952.168, Time=0.01 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=992.429, Time=0.01 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=915.480, Time=0.03 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=914.401, Time=0.05 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : AIC=914.893, Time=0.12 sec
#  ARIMA(2,0,3)(0,0,0)[0] intercept   : AIC=916.658, Time=0.18 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=912.659, Time=0.04 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=950.147, Time=0.04 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=912.260, Time=0.03 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=914.196, Time=0.03 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=912.878, Time=0.10 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=911.512, Time=0.04 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=912.913, Time=0.02 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=913.563, Time=0.04 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=913.553, Time=0.04 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=911.834, Time=0.03 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=912.298, Time=0.08 sec
#
# Best model:  ARIMA(2,0,0)(0,0,0)[0]
# Total fit time: 1.066 seconds

# %% [markdown]
# ## FB PROPHET PRACTICE

# %%
def renaming(df):
    df.reset_index(inplace = True)
    df.rename(columns={'update_date':'ds','confirmed_cases': 'y'}, inplace = True)
    
for df in list_provinces:
    renaming(df)

# %%
df.head()

# %%
for df in list_provinces:
    ax = df.set_index('ds').plot(figsize=(10, 6))
    ax.set_ylabel('daily confirmed cases ')
    ax.set_xlabel('Date')

plt.show()

# %% [markdown]
# We don't have enough data for fbprophet since the time interval was every several hours not by days our data had shortened significantly. We can make our data longer by looking at update by hours. But to save time we will just demonstrate the basics of how to use fbprophet below with an example csv.

# %%
df = pd.read_csv('example.csv')

# %%
from fbprophet.plot import plot_plotly, plot_components_plotly
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
m= Prophet()
m.fit(df)
    
#get future dates/ forecast
future = m.make_future_dataframe(periods=365)
forecast = m.predict(future)
    
#plot
m.plot(forecast)
m.plot_components(forecast)
    
plot_plotly(m, forecast)
plot_components_plotly(m, forecast)

# %%
forecast.head()

# %%
forecast_df = forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']]
metric_df = forecast_df.set_index('ds')[['yhat']].join(df.set_index('ds')[['y']])

#drop nan 
metric_df.dropna(inplace = True)
mse = mean_squared_error(metric_df.y, metric_df.yhat)
mae = mean_absolute_error(metric_df.y, metric_df.yhat)
print('mse:', mse)
print('mae:', mae)
